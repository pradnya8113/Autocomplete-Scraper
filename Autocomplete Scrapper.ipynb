# %%
import requests
import time
import json
from collections import deque

# %%
BASE_URL = "http://35.200.185.69:8000/v1/autocomplete?query="

# %%
RATE_LIMIT_SLEEP = 2  # Adjust based on API behavior

# %%
# Output file to store results
OUTPUT_FILE = "names.json"

# Store discovered names
found_names = set()

# %%
def fetch_names(query):
    global request_count  # Ensure we're modifying the global variable
    request_count += 1  # Increment request count

    try:
        response = requests.get(BASE_URL + query)
        print(f"Request #{request_count}: {BASE_URL}{query}")  # Debug print
        if response.status_code == 200:
            return response.json().get("results", [])
        elif response.status_code == 429:
            print("Rate limit hit. Sleeping...")
            time.sleep(RATE_LIMIT_SLEEP)
            return fetch_names(query)  # Recursive call still increments count
        else:
            print(f"Error {response.status_code}: {response.text}")
            return []
    except requests.exceptions.RequestException as e:
        print(f"Request failed: {e}")
        return []

# %%
def extract_names():
    """Extract all names using BFS traversal."""
    queue = deque([chr(i) for i in range(97, 123)])  # Start with a-z

    while queue:
        query = queue.popleft()
        print(f"Processing query: {query}, Queue size: {len(queue)}")  # Debug log
        suggestions = fetch_names(query)

        for name in suggestions:
            if name not in found_names:
                found_names.add(name)
                queue.append(name)  # Explore further completions

        # Save progress periodically
        with open(OUTPUT_FILE, "w") as f:
            json.dump(list(found_names), f, indent=4)

        time.sleep(0.5)  # Increased delay to prevent overwhelming the server

# %%
if __name__ == "__main__":
    extract_names()
    print(f"Extraction completed. {len(found_names)} names saved to {OUTPUT_FILE}.")
# Out:
# Processing query: a, Queue size: 25
# Request #2: http://35.200.185.69:8000/v1/autocomplete?query=a
# Processing query: b, Queue size: 24
# Request #3: http://35.200.185.69:8000/v1/autocomplete?query=b
# Processing query: c, Queue size: 23
# Request #4: http://35.200.185.69:8000/v1/autocomplete?query=c
# Processing query: d, Queue size: 22
# Request #5: http://35.200.185.69:8000/v1/autocomplete?query=d
# Processing query: e, Queue size: 21
# Request #6: http://35.200.185.69:8000/v1/autocomplete?query=e
# Processing query: f, Queue size: 20
# Request #7: http://35.200.185.69:8000/v1/autocomplete?query=f
# Processing query: g, Queue size: 19
# Request #8: http://35.200.185.69:8000/v1/autocomplete?query=g
# Processing query: h, Queue size: 18
# Request #9: http://35.200.185.69:8000/v1/autocomplete?query=h
# Processing query: i, Queue size: 17
# Request #10: http://35.200.185.69:8000/v1/autocomplete?query=i
# Processing query: j, Queue size: 16
# Request #11: http://35.200.185.69:8000/v1/autocomplete?query=j
# Processing query: k, Queue size: 15
# Request #12: http://35.200.185.69:8000/v1/autocomplete?query=k
# Processing query: l, Queue size: 14
# Request #13: http://35.200.185.69:8000/v1/autocomplete?query=l
# Processing query: m, Queue size: 13
# Request #14: http://35.200.185.69:8000/v1/autocomplete?query=m
# Processing query: n, Queue size: 12
# Request #15: http://35.200.185.69:8000/v1/autocomplete?query=n
# Processing query: o, Queue size: 11
# Request #16: http://35.200.185.69:8000/v1/autocomplete?query=o
# Processing query: p, Queue size: 10
# Request #17: http://35.200.185.69:8000/v1/autocomplete?query=p
# Processing query: q, Queue size: 9
# Request #18: http://35.200.185.69:8000/v1/autocomplete?query=q
# Processing query: r, Queue size: 8
# Request #19: http://35.200.185.69:8000/v1/autocomplete?query=r
# Processing query: s, Queue size: 7
# Request #20: http://35.200.185.69:8000/v1/autocomplete?query=s
# Processing query: t, Queue size: 6
# Request #21: http://35.200.185.69:8000/v1/autocomplete?query=t
# Processing query: u, Queue size: 5
# Request #22: http://35.200.185.69:8000/v1/autocomplete?query=u
# Processing query: v, Queue size: 4
# Request #23: http://35.200.185.69:8000/v1/autocomplete?query=v
# Processing query: w, Queue size: 3
# Request #24: http://35.200.185.69:8000/v1/autocomplete?query=w
# Processing query: x, Queue size: 2
# Request #25: http://35.200.185.69:8000/v1/autocomplete?query=x
# Processing query: y, Queue size: 1
# Request #26: http://35.200.185.69:8000/v1/autocomplete?query=y
# Processing query: z, Queue size: 0
# Request #27: http://35.200.185.69:8000/v1/autocomplete?query=z
# Extraction completed. 260 names saved to names.json.
